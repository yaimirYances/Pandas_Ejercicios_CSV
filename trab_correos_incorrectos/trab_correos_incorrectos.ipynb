# %%
import pandas as pd

# %%
carga = pd.read_csv("datoscorreos - Sheet1.csv")
df = pd.DataFrame(carga)
df
# Out:
#                                    correos
# 0   correo                alpip_ao19@hotma
# 1                    ramsu_2000hotmail.com
# 2                  email..email@domain.com
# 3                       email@domain.co.jp
# 4                    1234567890@domain.com
# 5                              @domain.com
# 6                            theraperitao@
# 7                         email@domain.com
# 8                             plainaddress
# 9            firstname.lastname@domain.com
# 10                      "email"@domain.com
# 11                              va.z.tardo
# 12                       email@domain..com
# 13                       .email@domain.com
# 14                     wiam_94@hotmail,com
# 15                ste. roz. n @hotmail.com
# 16                                      no
# 17                                       0
# 18                                mi_26387
# 19                             pro+galado@
# 20                    email@domain-one.com
# ...
