# %%
import pandas as pd

# %%
carga = pd.read_csv("datos.csv")
df = pd.DataFrame(carga)
df
# Out:
#     No.        Grupo red social  Unnamed: 3 Unnamed: 4         Unnamed: 5  \
# 0   1.0  Jw1Y-zhQURU  Instagram         NaN  Categoría                NaN
# 1   NaN          NaN        NaN         NaN   Deportes               ESPN
# 2   NaN          NaN        NaN         NaN     Gaming          PewDiePie
# 3   NaN          NaN        NaN         NaN      Vlogs       Amelia Liana
# 4   NaN          NaN        NaN         NaN        NaN                NaN
# 5   NaN          NaN        NaN         NaN        NaN                NaN
# 6   2.0      Is-2345   Facebook         NaN  Categoría                NaN
# 7   NaN          NaN        NaN         NaN  Educación          CCTMexico
# 8   NaN          NaN        NaN         NaN    Comedia        Flyingkitty
# 9   NaN          NaN        NaN         NaN    Comedia          PewDiePie
# 10  NaN          NaN        NaN         NaN      Vlogs           Frannerd
# 11  NaN          NaN        NaN         NaN        NaN                NaN
# ...

# %%
# ARREGLADO DATOS - QUITAR ESPACIOS EN BLANCO
df = df.dropna(how="all")
df
# Out:
#     No.        Grupo red social  Unnamed: 3 Unnamed: 4         Unnamed: 5  \
# 0   1.0  Jw1Y-zhQURU  Instagram         NaN  Categoría                NaN
# 1   NaN          NaN        NaN         NaN   Deportes               ESPN
# 2   NaN          NaN        NaN         NaN     Gaming          PewDiePie
# 3   NaN          NaN        NaN         NaN      Vlogs       Amelia Liana
# 6   2.0      Is-2345   Facebook         NaN  Categoría                NaN
# 7   NaN          NaN        NaN         NaN  Educación          CCTMexico
# 8   NaN          NaN        NaN         NaN    Comedia        Flyingkitty
# 9   NaN          NaN        NaN         NaN    Comedia          PewDiePie
# 10  NaN          NaN        NaN         NaN      Vlogs           Frannerd
# 13  3.0      Is-4076    Twitter         NaN  Categoría                NaN
# 14  NaN          NaN        NaN         NaN     Música               Pogo
# 15  NaN          NaN        NaN         NaN     Música  Zelda soundtracks
# ...

# %%
list(df)
# Out:
# ['No.',
#  'Grupo',
#  'red social',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7']

# %%
# RELLENAR DATOS POR COLUMNAS
df["red social"]=df["red social"].fillna(method="ffill")
# Out:
# /tmp/ipykernel_30642/3961499905.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["red social"]=df["red social"].fillna(method="ffill")

# %%
df
# Out:
#     No.        Grupo red social  Unnamed: 3 Unnamed: 4         Unnamed: 5  \
# 0   1.0  Jw1Y-zhQURU  Instagram         NaN  Categoría                NaN
# 1   NaN          NaN  Instagram         NaN   Deportes               ESPN
# 2   NaN          NaN  Instagram         NaN     Gaming          PewDiePie
# 3   NaN          NaN  Instagram         NaN      Vlogs       Amelia Liana
# 6   2.0      Is-2345   Facebook         NaN  Categoría                NaN
# 7   NaN          NaN   Facebook         NaN  Educación          CCTMexico
# 8   NaN          NaN   Facebook         NaN    Comedia        Flyingkitty
# 9   NaN          NaN   Facebook         NaN    Comedia          PewDiePie
# 10  NaN          NaN   Facebook         NaN      Vlogs           Frannerd
# 13  3.0      Is-4076    Twitter         NaN  Categoría                NaN
# 14  NaN          NaN    Twitter         NaN     Música               Pogo
# 15  NaN          NaN    Twitter         NaN     Música  Zelda soundtracks
# ...

# %%
df["Grupo"]=df["Grupo"].ffill()
df
# Out:
# /tmp/ipykernel_30642/3422670727.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Grupo"]=df["Grupo"].ffill()
#     No.        Grupo red social  Unnamed: 3 Unnamed: 4         Unnamed: 5  \
# 0   1.0  Jw1Y-zhQURU  Instagram         NaN  Categoría                NaN
# 1   NaN  Jw1Y-zhQURU  Instagram         NaN   Deportes               ESPN
# 2   NaN  Jw1Y-zhQURU  Instagram         NaN     Gaming          PewDiePie
# 3   NaN  Jw1Y-zhQURU  Instagram         NaN      Vlogs       Amelia Liana
# 6   2.0      Is-2345   Facebook         NaN  Categoría                NaN
# 7   NaN      Is-2345   Facebook         NaN  Educación          CCTMexico
# 8   NaN      Is-2345   Facebook         NaN    Comedia        Flyingkitty
# ...
