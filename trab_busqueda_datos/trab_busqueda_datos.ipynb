# %%
import pandas as pd
import numpy as np

# %%
minutos = pd.read_csv("student-mat.csv")
df = pd.DataFrame(minutos)
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.dtypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
#DIVIDAMOS EN 2 DATAFRAME
df1 = df.loc[(df["school"]=="GP")]
df1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1  at_home     other
# 2       GP   F   15       U     LE3       T     1     1  at_home     other
# 3       GP   F   15       U     GT3       T     4     2   health  services
# 4       GP   F   16       U     GT3       T     3     3    other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...       ...
# 344     GP   F   18       U     GT3       T     2     3  at_home     other
# 345     GP   F   18       U     GT3       T     3     2    other  services
# 346     GP   M   18       R     GT3       T     4     3  teacher  services
# 347     GP   M   18       U     GT3       T     4     3  teacher     other
# 348     GP   F   17       U     GT3       T     4     3   health     other
#
# ...

# %%
#DIVIDAMOS EN 2 DATAFRAME
df2 = df.loc[(df["school"]=="MS")]
df2.head()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 349     MS   M   18       R     GT3       T     3     2    other     other
# 350     MS   M   19       R     GT3       T     1     1    other  services
# 351     MS   M   17       U     GT3       T     3     3   health     other
# 352     MS   M   18       U     LE3       T     1     3  at_home  services
# 353     MS   M   19       R     GT3       T     1     1    other     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 349  ...      2        5      5     5     5      5       10  11  13  13
# 350  ...      5        4      4     3     3      2        8   8   7   8
# 351  ...      4        5      4     2     3      3        2  13  13  13
# 352  ...      4        3      3     2     3      3        7   8   7   8
# 353  ...      4        4      4     3     3      5        4   8   8   8
#
# [5 rows x 33 columns]

# %%
#CUANTOS ESTUANTES ESTAN VIAJANDO MAS DE 1 HORA
df1.where(df1.traveltime==4).traveltime.count()
# Out:
# 7

# %%
#ESTADISTICAS BASICAS
df1.traveltime.describe()
# Out:
# count    349.000000
# mean       1.386819
# std        0.666910
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        4.000000
# Name: traveltime, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure
df1.traveltime.hist()
# Out:
# <Axes: >

# %%
#CUANTOS ESTUDIANTES NO TIENEN INTERNET EN CASA
df1.where(df1.internet=="no").internet.count()
# Out:
# 52

# %%
#COMO UTILIZAR UN IF EN EL DATAFRAME
#CUANTOS ESTUDIANTES REQUIEREN APOYO DE UN TUTOR

df1.where(df1.famrel==1).famrel.count()
# Out:
# 6

# %%
#
tabla = pd.pivot_table(df1, index="sex", values="famrel")
tabla
# Out:
#        famrel
# sex
# F    3.901639
# M    4.024096

# %%
tabla = pd.pivot_table(df1, index=["sex","Mjob"], values="famrel")
tabla
# Out:
#                 famrel
# sex Mjob
# F   at_home   3.750000
#     health    3.555556
#     other     4.076923
#     services  3.897959
#     teacher   3.933333
# M   at_home   4.153846
#     health    3.928571
#     other     3.947368
#     services  4.244444
#     teacher   3.864865

# %%
#TABLA PIVOTE USARIO
import numpy as np
tabla = pd.pivot_table(df1, index=["sex"], values="famrel", aggfunc=[np.mean,min,max])
tabla
# Out:
#          mean    min    max
#        famrel famrel famrel
# sex
# F    3.901639      1      5
# M    4.024096      1      5

# %%
if df1.where(df1.famrel==1).famrel.count() > 0:
    print("Se requiere atencion especializada")
    tutores = df1.where(df1.famrel==1).famrel.count()/2
    print("Se necesitan ",int(round(tutores)), " tutores")
# Out:
# Se requiere atencion especializada
# Se necesitan  3  tutores
