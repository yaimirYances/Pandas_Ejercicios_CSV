# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
minutos = pd.read_csv("student-mat.csv")
df = pd.DataFrame(minutos)
df
# Out:
#      nombre school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0    yaimir     GP   F   80       U     GT3       A     4     4   at_home
# 1       NaN     GP   F   18       U     GT3       A     4     4   at_home
# 2       NaN     GP   F   17       U     GT3       T     1     1   at_home
# 3       NaN     GP   F   15       U     LE3       T     1     1   at_home
# 4       NaN     GP   F   15       U     GT3       T     4     2    health
# ..      ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 391     NaN     MS   M   20       U     LE3       A     2     2  services
# 392     NaN     MS   M   17       U     LE3       T     3     1  services
# 393     NaN     MS   M   21       R     GT3       T     1     1     other
# 394     NaN     MS   M   18       R     LE3       T     3     2  services
# 395     NaN     MS   M   19       U     LE3       T     1     1     other
#
#      ... famrel freetime goout  Dalc  Walc  health absences  G1  G2  G3
# ...

# %%
df.dtypes
# Out:
# nombre        object
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396 entries, 0 to 395
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   nombre      1 non-null      object
#  1   school      396 non-null    object
#  2   sex         396 non-null    object
#  3   age         396 non-null    int64
#  4   address     396 non-null    object
#  5   famsize     396 non-null    object
#  6   Pstatus     396 non-null    object
#  7   Medu        396 non-null    int64
#  8   Fedu        396 non-null    int64
#  9   Mjob        396 non-null    object
#  10  Fjob        396 non-null    object
#  11  reason      396 non-null    object
#  12  guardian    396 non-null    object
#  13  traveltime  396 non-null    int64
#  14  studytime   396 non-null    int64
#  15  failures    396 non-null    int64
#  16  schoolsup   396 non-null    object
#  17  famsup      396 non-null    object
#  18  paid        396 non-null    object
# ...

# %%
#RELLENAR DATOS NaN CON DATOS
df["health"].fillna(0,inplace=True)
df
# Out:
#      nombre school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0    yaimir     GP   F   80       U     GT3       A     4     4   at_home
# 1       NaN     GP   F   18       U     GT3       A     4     4   at_home
# 2       NaN     GP   F   17       U     GT3       T     1     1   at_home
# 3       NaN     GP   F   15       U     LE3       T     1     1   at_home
# 4       NaN     GP   F   15       U     GT3       T     4     2    health
# ..      ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 391     NaN     MS   M   20       U     LE3       A     2     2  services
# 392     NaN     MS   M   17       U     LE3       T     3     1  services
# 393     NaN     MS   M   21       R     GT3       T     1     1     other
# 394     NaN     MS   M   18       R     LE3       T     3     2  services
# 395     NaN     MS   M   19       U     LE3       T     1     1     other
#
#      ... famrel freetime goout  Dalc  Walc  health absences  G1  G2  G3
# ...

# %%
#CREANDO 2 DATAFRAME PARA TRABAJAR
df1 = df.loc[(df["school"]=="GP")]
df2 = df.loc[(df["school"]=="MS")]

# %%
conteo = len(df1[(df1["absences"]>10)&(df1["failures"]>2)])
conteo
# Out:
# 2

# %%
df1.loc[((df1["absences"]>10)&(df1["failures"]>2),("health","sex","traveltime"))]
# Out:
#      health sex  traveltime
# 19        5   M           1
# 248       1   M           1

# %%
# FILTRAR ALUMNOS MAYORES A 20 AÑOS
df1[df1["age"]>20].iloc[0][["nombre","sex"]]
# Out:
# nombre    yaimir
# sex            F
# Name: 0, dtype: object

# %%
#CORRELACION ENTRE TIEMPO LIBRE Y CONSUMO DE ALCOHOL
df1["freetime"].corr(df1["Dalc"])
# Out:
# 0.17804404426568526

# %%
df1["Dalc"].corr(df1["famrel"])
# Out:
# -0.0874035256379868

# %%
df1.Dalc.value_counts().plot(kind="pie", labels=None, autopct="%1.2f%%", shadow=True, startangle=180, fontsize=12, pctdistance=1.1, labeldistance=1.4)
plt.title("Consumo de alcohol")
mymap = {"muy bajo":1,"Bajo":2,"Medio":3,"Alto":4,"Muy alto":5}
plt.legend(loc="best", labels=mymap)
plt.ylabel("")
plt.axis("equal")
# Out:
# (-1.0999998301640233,
#  1.0999964334444874,
#  -1.099998711135126,
#  1.0999949355356011)

# %%
df1.Dalc.value_counts()
# Out:
# Dalc
# 1    250
# 2     67
# 3     19
# 5      8
# 4      6
# Name: count, dtype: int64

# %%
#TRATANDO LOS COLORES https://seaborn.pydata.org/generated/seaborn.pairplot.html
import seaborn as sns
sns.set(style="ticks", color_codes=True)
nuevo = df[["G1","G2","G3"]].copy() #PARA NO MODIFICAR LOS DATOS copy()
g = sns.pairplot(nuevo, kind="reg")
# Out:
# /home/atom/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
